# %% [markdown]
# <a href="https://colab.research.google.com/github/sejalmuluk27/personal-information-manager/blob/main/personal_info.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("=" * 40)
print("   PERSONAL INFORMATION MANAGER")
print("=" * 40)

# Personal information
name = "Sejal Muluk"
age = 20
city = "Pune"
hobby = "Painting"

# User input
favorite_food = input("Enter your favorite food: ")
favorite_color = input("Enter your favorite color: ")

# Display information
print("\n--- PERSONAL DETAILS ---")
print(f"Name           : {name}")
print(f"Age            : {age} years")
print(f"City           : {city}")
print(f"Hobby          : {hobby}")

print("\n--- USER PREFERENCES ---")
print(f"Favorite Food  : {favorite_food.title()}")
print(f"Favorite Color : {favorite_color.title()}")

print("\nThank you for using the program!")
# Out:
# ...
#    PERSONAL INFORMATION MANAGER
# ...
# Enter your favorite food: Pasta
# Enter your favorite color: White
#
# --- PERSONAL DETAILS ---
# Name           : Sejal Muluk
# Age            : 20 years
# City           : Pune
# Hobby          : Painting
#
# --- USER PREFERENCES ---
# Favorite Food  : Pasta
# Favorite Color : White
#
# Thank you for using the program!
